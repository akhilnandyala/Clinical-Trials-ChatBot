# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from pathlib import Path
import string
import re
import joblib
import json
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
nltk.download('wordnet')
nltk.download('geograpy')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\akhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True
# [nltk_data] Error loading geograpy: Package 'geograpy' not found in
# [nltk_data]     index
# False

# %%
def load_doc(jsonFile):
    with open(jsonFile) as file:
        Json_data = json.loads(file.read())
    return Json_data

data = load_doc('./intents.json')
data
# Out:
# {'intents': [{'tag': 'start_conversation',
#    'patterns': ['Hi there',
#     'Is anyone there?',
#     'Hey',
#     'Hola',
#     'Hello',
#     'Good day',
#     'Hi'],
#    'responses': ['Hello',
#     'Happy to have you here',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context': ['']},
#   {'tag': 'what_are_you',
#    'patterns': ['What is your name?',
#     'what are you?',
#     'who are you?',
#     'your name pls?'],
#    'responses': ["Hi, I'm  Bowhead Bot",
#     "I'm Bowhead Bot ",
#     'Call me Bowhead Bot'],
#    'context': ['']},
#   {'tag': 'end_conversation',
#    'patterns': ['Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['Have a lovely Day!',
#     'Bye',
#     'Buhbyee !',
#     'Happy to help you'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure', 'Have fun'],
#    'context': ['']},
#   {'tag': 'confused',
#    'patterns': [],
#    'responses': ['Sorry, kindly rephrase the question',
#     "Sorry, can't understand you",
#     'Please give me more information',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'options',
#    'patterns': ['How can you help me?',
#     'What can you do?',
#     'What help you provide?',
#     'How can you be helpful?',
#     'What support do you offered',
#     'What do you know?',
#     'what help?',
#     'What are you about?'],
#    'responses': ['I can help you get to know more about Bowhead Health and the services we provide, in particular, I can help you find Covid trails suitable to your needs'],
#    'context': ['']},
#   {'tag': 'covid_trials',
#    'patterns': ['What can you tell me about covid trials',
#     'I need some info about covid trials',
#     'Covid trials info needed',
#     'I want to know about covid trials',
#     'Show me covid trials info'],
#    'responses': ['Sure let me get that info for you',
#     'I will get that info for you',
#     'Getting the covid trails info',
#     'Gathering the trials information '],
#    'context': ['']}]}

# %%
def frame_data(feat_1,feat_2,is_pattern):
    is_pattern = is_pattern
    df = pd.DataFrame(columns=[feat_1,feat_2])
    for intent in data['intents']:
        if is_pattern:
            for pattern in intent['patterns']:
                w = pattern
                df_to_append = pd.Series([w,intent['tag']], index = df.columns)
                df = df.append(df_to_append,ignore_index=True)
        else:
            for response in intent['responses']:
                w = response
                df_to_append = pd.Series([w,intent['tag']], index = df.columns)
                df = df.append(df_to_append,ignore_index=True)
    return df

# %%
questions_df = frame_data('questions','labels',True)
questions_df
# Out:
#                                   questions              labels
# 0                                  Hi there  start_conversation
# 1                          Is anyone there?  start_conversation
# 2                                       Hey  start_conversation
# 3                                      Hola  start_conversation
# 4                                     Hello  start_conversation
# 5                                  Good day  start_conversation
# 6                                        Hi  start_conversation
# 7                        What is your name?        what_are_you
# 8                             what are you?        what_are_you
# 9                              who are you?        what_are_you
# 10                           your name pls?        what_are_you
# 11                                      Bye    end_conversation
# 12                            See you later    end_conversation
# 13                                  Goodbye    end_conversation
# 14                Nice chatting to you, bye    end_conversation
# 15                           Till next time    end_conversation
# 16                                   Thanks              thanks
# 17                                Thank you              thanks
# 18                           That's helpful              thanks
# 19                          Awesome, thanks              thanks
# 20                    Thanks for helping me              thanks
# 21                     How can you help me?             options
# 22                         What can you do?             options
# 23                   What help you provide?             options
# 24                  How can you be helpful?             options
# 25              What support do you offered             options
# 26                        What do you know?             options
# 27                               what help?             options
# 28                      What are you about?             options
# 29  What can you tell me about covid trials        covid_trials
# 30      I need some info about covid trials        covid_trials
# 31                 Covid trials info needed        covid_trials
# 32        I want to know about covid trials        covid_trials
# 33                Show me covid trials info        covid_trials

# %%
responses_df = frame_data('responses','labels',False)
responses_df
# Out:
#                                             responses              labels
# 0                                               Hello  start_conversation
# 1                              Happy to have you here  start_conversation
# 2                               Good to see you again  start_conversation
# 3                           Hi there, how can I help?  start_conversation
# 4                                Hi, I'm  Bowhead Bot        what_are_you
# 5                                    I'm Bowhead Bot         what_are_you
# 6                                 Call me Bowhead Bot        what_are_you
# 7                                  Have a lovely Day!    end_conversation
# 8                                                 Bye    end_conversation
# 9                                           Buhbyee !    end_conversation
# 10                                  Happy to help you    end_conversation
# 11                                     Happy to help!              thanks
# 12                                          Any time!              thanks
# 13                                        My pleasure              thanks
# 14                                           Have fun              thanks
# 15                Sorry, kindly rephrase the question            confused
# 16                        Sorry, can't understand you            confused
# 17                    Please give me more information            confused
# 18                              Not sure I understand            confused
# 19  I can help you get to know more about Bowhead ...             options
# 20                  Sure let me get that info for you        covid_trials
# 21                       I will get that info for you        covid_trials
# 22                      Getting the covid trails info        covid_trials
# 23                  Gathering the trials information         covid_trials

# %% [markdown]
# # For creating tokens and vocab of training data;this vocab is later used when testing new user input(testing the bot)

# %%
lemmatizer = WordNetLemmatizer()

vocab = Counter()
labels = []
def tokenizer(entry):
    tokens = entry.split()
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    tokens = [re_punc.sub('', w) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    tokens = [lemmatizer.lemmatize(w.lower()) for w in tokens]
#     stop_words = set(stopwords.words('english'))
#     tokens = [w for w in tokens if not w in stop_words]
    tokens = [word.lower() for word in tokens if len(word) > 1]
    return tokens

def remove_stop_words(tokenizer,df,feature):
    doc_without_stopwords = []
    for entry in df[feature]:
        tokens = tokenizer(entry)
        joblib.dump(tokens,'tokens.pkl')
        doc_without_stopwords.append(' '.join(tokens))
    df[feature] = doc_without_stopwords
    return 

def create_vocab(tokenizer,df,feature):
    for entry in df[feature]:
        tokens = tokenizer(entry)   
        vocab.update(tokens)
    joblib.dump(vocab,'vocab.pkl')
    return 


create_vocab(tokenizer,questions_df,'questions')
remove_stop_words(tokenizer,questions_df,'questions')

# %% [markdown]
# # Creating training and test data and storing the indexes

# %%
# Creating a test list containing only the first question of each group after grouping them according to their labels.
test_list = list(questions_df.groupby(by='labels',as_index=False).first()['questions'])
test_list

# The index of the above test observations taken from the dataframe df1
test_index = []
for i,_ in enumerate(test_list):
    idx = questions_df[questions_df.questions == test_list[i]].index[0]
    test_index.append(idx)
test_index

# Train index
train_index = [i for i in questions_df.index if i not in test_index]
train_index
# Out:
# ['what can you tell me about covid trial',
#  'bye',
#  'how can you help me',
#  'hi there',
#  'thanks',
#  'what is your name']
# [29, 11, 21, 0, 16, 7]
# [1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  8,
#  9,
#  10,
#  12,
#  13,
#  14,
#  15,
#  17,
#  18,
#  19,
#  20,
#  22,
#  23,
#  24,
#  25,
#  26,
#  27,
#  28,
#  30,
#  31,
#  32,
#  33]

# %% [markdown]
# # Initializing a tokenizer, fitting it on to questions df and encoding the questions_df

# %%
def encoder(df,feature):
#     text = ' '.join(list(vocab.keys()))
#     from tensorflow.keras.preprocessing.text import text_to_word_sequence
    t = Tokenizer()
    entries = [entry for entry in df[feature]]
    print(entries)
    #step1 To create dictionary having 'keys' as words from each entry(sentences) and 'values' are randomly assigned by tokenizer.
    t.fit_on_texts(entries)
    print(t.word_index)
    joblib.dump(t,'tokenizer_t.pkl')
    vocab_size = len(t.word_index) + 1
    print(vocab_size)
    entries = [entry for entry in df[feature]]
    max_length = max([len(s.split()) for s in entries])
    print(max_length)
    #setp2 To see the output of the dataframe when dictionary 'values' from the above created dictionary in step1 are used in the place of the words in the sentences
    encoded = t.texts_to_sequences(entries)
    print(encoded)
    padded = pad_sequences(encoded, maxlen=max_length, padding='post')
    return padded, vocab_size

# %%
X,vocab_size = encoder(questions_df,'questions')
X
questions_df_encoded = pd.DataFrame(X)
questions_df_encoded['labels'] = questions_df.labels
questions_df_encoded
# Out:
# ['hi there', 'is anyone there', 'hey', 'hola', 'hello', 'good day', 'hi', 'what is your name', 'what are you', 'who are you', 'your name pls', 'bye', 'see you later', 'goodbye', 'nice chatting to you bye', 'till next time', 'thanks', 'thank you', 'thats helpful', 'awesome thanks', 'thanks for helping me', 'how can you help me', 'what can you do', 'what help you provide', 'how can you be helpful', 'what support do you offered', 'what do you know', 'what help', 'what are you about', 'what can you tell me about covid trial', 'need some info about covid trial', 'covid trial info needed', 'want to know about covid trial', 'show me covid trial info']
# {'you': 1, 'what': 2, 'covid': 3, 'trial': 4, 'me': 5, 'can': 6, 'about': 7, 'are': 8, 'thanks': 9, 'help': 10, 'do': 11, 'info': 12, 'hi': 13, 'there': 14, 'is': 15, 'your': 16, 'name': 17, 'bye': 18, 'to': 19, 'helpful': 20, 'how': 21, 'know': 22, 'anyone': 23, 'hey': 24, 'hola': 25, 'hello': 26, 'good': 27, 'day': 28, 'who': 29, 'pls': 30, 'see': 31, 'later': 32, 'goodbye': 33, 'nice': 34, 'chatting': 35, 'till': 36, 'next': 37, 'time': 38, 'thank': 39, 'thats': 40, 'awesome': 41, 'for': 42, 'helping': 43, 'provide': 44, 'be': 45, 'support': 46, 'offered': 47, 'tell': 48, 'need': 49, 'some': 50, 'needed': 51, 'want': 52, 'show': 53}
# 54
# 8
# [[13, 14], [15, 23, 14], [24], [25], [26], [27, 28], [13], [2, 15, 16, 17], [2, 8, 1], [29, 8, 1], [16, 17, 30], [18], [31, 1, 32], [33], [34, 35, 19, 1, 18], [36, 37, 38], [9], [39, 1], [40, 20], [41, 9], [9, 42, 43, 5], [21, 6, 1, 10, 5], [2, 6, 1, 11], [2, 10, 1, 44], [21, 6, 1, 45, 20], [2, 46, 11, 1, 47], [2, 11, 1, 22], [2, 10], [2, 8, 1, 7], [2, 6, 1, 48, 5, 7, 3, 4], [49, 50, 12, 7, 3, 4], [3, 4, 12, 51], [52, 19, 22, 7, 3, 4], [53, 5, 3, 4, 12]]
# array([[13, 14,  0,  0,  0,  0,  0,  0],
#        [15, 23, 14,  0,  0,  0,  0,  0],
#        [24,  0,  0,  0,  0,  0,  0,  0],
#        [25,  0,  0,  0,  0,  0,  0,  0],
#        [26,  0,  0,  0,  0,  0,  0,  0],
#        [27, 28,  0,  0,  0,  0,  0,  0],
#        [13,  0,  0,  0,  0,  0,  0,  0],
#        [ 2, 15, 16, 17,  0,  0,  0,  0],
#        [ 2,  8,  1,  0,  0,  0,  0,  0],
#        [29,  8,  1,  0,  0,  0,  0,  0],
#        [16, 17, 30,  0,  0,  0,  0,  0],
#        [18,  0,  0,  0,  0,  0,  0,  0],
#        [31,  1, 32,  0,  0,  0,  0,  0],
#        [33,  0,  0,  0,  0,  0,  0,  0],
#        [34, 35, 19,  1, 18,  0,  0,  0],
#        [36, 37, 38,  0,  0,  0,  0,  0],
#        [ 9,  0,  0,  0,  0,  0,  0,  0],
#        [39,  1,  0,  0,  0,  0,  0,  0],
#        [40, 20,  0,  0,  0,  0,  0,  0],
#        [41,  9,  0,  0,  0,  0,  0,  0],
#        [ 9, 42, 43,  5,  0,  0,  0,  0],
#        [21,  6,  1, 10,  5,  0,  0,  0],
#        [ 2,  6,  1, 11,  0,  0,  0,  0],
#        [ 2, 10,  1, 44,  0,  0,  0,  0],
#        [21,  6,  1, 45, 20,  0,  0,  0],
#        [ 2, 46, 11,  1, 47,  0,  0,  0],
#        [ 2, 11,  1, 22,  0,  0,  0,  0],
#        [ 2, 10,  0,  0,  0,  0,  0,  0],
#        [ 2,  8,  1,  7,  0,  0,  0,  0],
#        [ 2,  6,  1, 48,  5,  7,  3,  4],
#        [49, 50, 12,  7,  3,  4,  0,  0],
#        [ 3,  4, 12, 51,  0,  0,  0,  0],
#        [52, 19, 22,  7,  3,  4,  0,  0],
#        [53,  5,  3,  4, 12,  0,  0,  0]])
#      0   1   2   3   4  5  6  7              labels
# 0   13  14   0   0   0  0  0  0  start_conversation
# 1   15  23  14   0   0  0  0  0  start_conversation
# 2   24   0   0   0   0  0  0  0  start_conversation
# 3   25   0   0   0   0  0  0  0  start_conversation
# 4   26   0   0   0   0  0  0  0  start_conversation
# 5   27  28   0   0   0  0  0  0  start_conversation
# 6   13   0   0   0   0  0  0  0  start_conversation
# 7    2  15  16  17   0  0  0  0        what_are_you
# 8    2   8   1   0   0  0  0  0        what_are_you
# 9   29   8   1   0   0  0  0  0        what_are_you
# 10  16  17  30   0   0  0  0  0        what_are_you
# 11  18   0   0   0   0  0  0  0    end_conversation
# 12  31   1  32   0   0  0  0  0    end_conversation
# 13  33   0   0   0   0  0  0  0    end_conversation
# 14  34  35  19   1  18  0  0  0    end_conversation
# 15  36  37  38   0   0  0  0  0    end_conversation
# 16   9   0   0   0   0  0  0  0              thanks
# 17  39   1   0   0   0  0  0  0              thanks
# 18  40  20   0   0   0  0  0  0              thanks
# 19  41   9   0   0   0  0  0  0              thanks
# 20   9  42  43   5   0  0  0  0              thanks
# 21  21   6   1  10   5  0  0  0             options
# 22   2   6   1  11   0  0  0  0             options
# 23   2  10   1  44   0  0  0  0             options
# 24  21   6   1  45  20  0  0  0             options
# 25   2  46  11   1  47  0  0  0             options
# 26   2  11   1  22   0  0  0  0             options
# 27   2  10   0   0   0  0  0  0             options
# 28   2   8   1   7   0  0  0  0             options
# 29   2   6   1  48   5  7  3  4        covid_trials
# 30  49  50  12   7   3  4  0  0        covid_trials
# 31   3   4  12  51   0  0  0  0        covid_trials
# 32  52  19  22   7   3  4  0  0        covid_trials
# 33  53   5   3   4  12  0  0  0        covid_trials

# %%
#Creating 2 observations with 'confused' label and appending them to dataframe.
for i in range(0,2):
    dt = [0]*8
    dt.append('confused')
    dt = [dt]
    pd.DataFrame(dt).rename(columns = {8:'labels'})
    questions_df_encoded = questions_df_encoded.append(pd.DataFrame(dt).rename(columns = {8:'labels'}),ignore_index=True)
    
questions_df_encoded
# Out:
#    0  1  2  3  4  5  6  7    labels
# 0  0  0  0  0  0  0  0  0  confused
#    0  1  2  3  4  5  6  7    labels
# 0  0  0  0  0  0  0  0  0  confused
#      0   1   2   3   4  5  6  7              labels
# 0   13  14   0   0   0  0  0  0  start_conversation
# 1   15  23  14   0   0  0  0  0  start_conversation
# 2   24   0   0   0   0  0  0  0  start_conversation
# 3   25   0   0   0   0  0  0  0  start_conversation
# 4   26   0   0   0   0  0  0  0  start_conversation
# 5   27  28   0   0   0  0  0  0  start_conversation
# 6   13   0   0   0   0  0  0  0  start_conversation
# 7    2  15  16  17   0  0  0  0        what_are_you
# 8    2   8   1   0   0  0  0  0        what_are_you
# 9   29   8   1   0   0  0  0  0        what_are_you
# 10  16  17  30   0   0  0  0  0        what_are_you
# 11  18   0   0   0   0  0  0  0    end_conversation
# 12  31   1  32   0   0  0  0  0    end_conversation
# 13  33   0   0   0   0  0  0  0    end_conversation
# 14  34  35  19   1  18  0  0  0    end_conversation
# 15  36  37  38   0   0  0  0  0    end_conversation
# 16   9   0   0   0   0  0  0  0              thanks
# 17  39   1   0   0   0  0  0  0              thanks
# 18  40  20   0   0   0  0  0  0              thanks
# 19  41   9   0   0   0  0  0  0              thanks
# 20   9  42  43   5   0  0  0  0              thanks
# 21  21   6   1  10   5  0  0  0             options
# 22   2   6   1  11   0  0  0  0             options
# 23   2  10   1  44   0  0  0  0             options
# 24  21   6   1  45  20  0  0  0             options
# 25   2  46  11   1  47  0  0  0             options
# 26   2  11   1  22   0  0  0  0             options
# 27   2  10   0   0   0  0  0  0             options
# 28   2   8   1   7   0  0  0  0             options
# 29   2   6   1  48   5  7  3  4        covid_trials
# 30  49  50  12   7   3  4  0  0        covid_trials
# 31   3   4  12  51   0  0  0  0        covid_trials
# 32  52  19  22   7   3  4  0  0        covid_trials
# 33  53   5   3   4  12  0  0  0        covid_trials
# 34   0   0   0   0   0  0  0  0            confused
# 35   0   0   0   0   0  0  0  0            confused

# %%
# Appending one of the confused labeled observation to train index
train_index.append(34)
# Appending one of the confused labeled observation to test index
test_index.append(35)

# %% [markdown]
# # Encoding the labels of questions_df_encoded and then later responses_df

# %%
# Encoding the 'labels' with values choosen(random) by labelEncoder 
from sklearn.preprocessing import LabelEncoder
lable_enc = LabelEncoder()

labl = lable_enc.fit_transform(questions_df_encoded.labels)
labl

mapper = {}
for index,key in enumerate(questions_df_encoded.labels):
    if key not in mapper.keys():
        mapper[key] = labl[index]
mapper
# Out:
# array([4, 4, 4, 4, 4, 4, 4, 6, 6, 6, 6, 2, 2, 2, 2, 2, 5, 5, 5, 5, 5, 3,
#        3, 3, 3, 3, 3, 3, 3, 1, 1, 1, 1, 1, 0, 0])
# {'start_conversation': 4,
#  'what_are_you': 6,
#  'end_conversation': 2,
#  'thanks': 5,
#  'options': 3,
#  'covid_trials': 1,
#  'confused': 0}

# %%
# Encoding the labels of responses dataframe df2 with values choosen from questions dataframe df1.
responses_df.labels = responses_df.labels.map(mapper).astype({'labels': 'int32'})
responses_df
responses_df.to_csv('./responses.csv')
# Out:
#                                             responses  labels
# 0                                               Hello       4
# 1                              Happy to have you here       4
# 2                               Good to see you again       4
# 3                           Hi there, how can I help?       4
# 4                                Hi, I'm  Bowhead Bot       6
# 5                                    I'm Bowhead Bot        6
# 6                                 Call me Bowhead Bot       6
# 7                                  Have a lovely Day!       2
# 8                                                 Bye       2
# 9                                           Buhbyee !       2
# 10                                  Happy to help you       2
# 11                                     Happy to help!       5
# 12                                          Any time!       5
# 13                                        My pleasure       5
# 14                                           Have fun       5
# 15                Sorry, kindly rephrase the question       0
# 16                        Sorry, can't understand you       0
# 17                    Please give me more information       0
# 18                              Not sure I understand       0
# 19  I can help you get to know more about Bowhead ...       3
# 20                  Sure let me get that info for you       1
# 21                       I will get that info for you       1
# 22                      Getting the covid trails info       1
# 23                  Gathering the trials information        1

# %% [markdown]
# # Creating train and test for the model based on the above calculated indexes

# %%
train = questions_df_encoded.loc[train_index]
test = questions_df_encoded.loc[test_index]


X_train = train.drop(columns=['labels'],axis=1)
y_train = train.labels
X_test = test.drop(columns=['labels'],axis=1)
y_test = test.labels

y_train =pd.get_dummies(y_train).values
y_test =pd.get_dummies(y_test).values

# %%
y_train[0].shape,y_test[0].shape
X_train.shape
# Out:
# ((7,), (7,))
# (29, 8)

# %%
max_length = X_train.shape[1]
max_length
output = 9
# Out:
# 8

# %% [markdown]
# # Model construction

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
checkpoint = ModelCheckpoint("model-v1.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 3, verbose = 1, min_delta = 0.0001)
callbacks = [early_stopping,checkpoint,reduce_lr]


def define_model(vocab_size, max_length):
    model = Sequential()
    model.add(Embedding(vocab_size,300, input_length=max_length))
    model.add(Conv1D(filters=64, kernel_size=4, activation='relu'))
    model.add(MaxPooling1D(pool_size=4))
    model.add(Flatten())
#     model.add(Dense(32, activation='relu'))
    model.add(Dense(7, activation='softmax'))
    
    
    # compile network
#     model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.compile(loss = 'categorical_crossentropy',
              # optimizer = Adam(lr=0.001),
              optimizer = 'adam',
              metrics = ['accuracy'])
    
    # summarize defined model
    model.summary()
#     plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
model = define_model(vocab_size, max_length)
# Out:
# WARNING:tensorflow:From C:\Users\akhil\anaconda3\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\akhil\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 8, 300)            16200
# _________________________________________________________________
# conv1d (Conv1D)              (None, 5, 64)             76864
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1, 64)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 455
# =================================================================
# Total params: 93,519
# Trainable params: 93,519
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=500, verbose=1,validation_data=(X_test,y_test),callbacks=callbacks)
# Out:
# Train on 29 samples, validate on 7 samples
# Epoch 1/500
#
# Epoch 00001: val_loss improved from inf to 1.92745, saving model to model-v1.h5
# 29/29 [==============================] - 0s 12ms/sample - loss: 1.9453 - acc: 0.2069 - val_loss: 1.9274 - val_acc: 0.2857
# Epoch 2/500
#
# Epoch 00002: val_loss improved from 1.92745 to 1.91414, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.8783 - acc: 0.6552 - val_loss: 1.9141 - val_acc: 0.2857
# Epoch 3/500
#
# Epoch 00003: val_loss improved from 1.91414 to 1.90205, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.8242 - acc: 0.6552 - val_loss: 1.9021 - val_acc: 0.2857
# Epoch 4/500
#
# Epoch 00004: val_loss improved from 1.90205 to 1.89077, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.7764 - acc: 0.6207 - val_loss: 1.8908 - val_acc: 0.2857
# Epoch 5/500
#
# Epoch 00005: val_loss improved from 1.89077 to 1.87997, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.7307 - acc: 0.6552 - val_loss: 1.8800 - val_acc: 0.2857
# Epoch 6/500
#
# Epoch 00006: val_loss improved from 1.87997 to 1.86958, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.6857 - acc: 0.6552 - val_loss: 1.8696 - val_acc: 0.2857
# Epoch 7/500
#
# Epoch 00007: val_loss improved from 1.86958 to 1.85888, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.6407 - acc: 0.6552 - val_loss: 1.8589 - val_acc: 0.2857
# Epoch 8/500
#
# Epoch 00008: val_loss improved from 1.85888 to 1.84790, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.5950 - acc: 0.6897 - val_loss: 1.8479 - val_acc: 0.2857
# Epoch 9/500
#
# Epoch 00009: val_loss improved from 1.84790 to 1.83673, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.5481 - acc: 0.6897 - val_loss: 1.8367 - val_acc: 0.2857
# Epoch 10/500
#
# Epoch 00010: val_loss improved from 1.83673 to 1.82616, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.5010 - acc: 0.6897 - val_loss: 1.8262 - val_acc: 0.2857
# Epoch 11/500
#
# Epoch 00011: val_loss improved from 1.82616 to 1.81607, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.4533 - acc: 0.6897 - val_loss: 1.8161 - val_acc: 0.2857
# Epoch 12/500
#
# Epoch 00012: val_loss improved from 1.81607 to 1.80654, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.4050 - acc: 0.6897 - val_loss: 1.8065 - val_acc: 0.2857
# Epoch 13/500
#
# Epoch 00013: val_loss improved from 1.80654 to 1.79719, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.3564 - acc: 0.6897 - val_loss: 1.7972 - val_acc: 0.2857
# Epoch 14/500
#
# Epoch 00014: val_loss improved from 1.79719 to 1.78826, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.3076 - acc: 0.6897 - val_loss: 1.7883 - val_acc: 0.2857
# Epoch 15/500
#
# Epoch 00015: val_loss improved from 1.78826 to 1.77973, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.2593 - acc: 0.6897 - val_loss: 1.7797 - val_acc: 0.2857
# Epoch 16/500
#
# Epoch 00016: val_loss improved from 1.77973 to 1.77187, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.2113 - acc: 0.7241 - val_loss: 1.7719 - val_acc: 0.2857
# Epoch 17/500
#
# Epoch 00017: val_loss improved from 1.77187 to 1.76449, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.1635 - acc: 0.7586 - val_loss: 1.7645 - val_acc: 0.2857
# Epoch 18/500
#
# Epoch 00018: val_loss improved from 1.76449 to 1.75708, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.1156 - acc: 0.7586 - val_loss: 1.7571 - val_acc: 0.2857
# Epoch 19/500
#
# Epoch 00019: val_loss improved from 1.75708 to 1.75057, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.0682 - acc: 0.7586 - val_loss: 1.7506 - val_acc: 0.2857
# Epoch 20/500
#
# Epoch 00020: val_loss improved from 1.75057 to 1.74431, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.0215 - acc: 0.7931 - val_loss: 1.7443 - val_acc: 0.2857
# Epoch 21/500
#
# Epoch 00021: val_loss improved from 1.74431 to 1.73841, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.9753 - acc: 0.8621 - val_loss: 1.7384 - val_acc: 0.2857
# Epoch 22/500
#
# Epoch 00022: val_loss improved from 1.73841 to 1.73379, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.9299 - acc: 0.8621 - val_loss: 1.7338 - val_acc: 0.2857
# Epoch 23/500
#
# Epoch 00023: val_loss improved from 1.73379 to 1.72985, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.8853 - acc: 0.8621 - val_loss: 1.7299 - val_acc: 0.2857
# Epoch 24/500
#
# Epoch 00024: val_loss improved from 1.72985 to 1.72603, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.8421 - acc: 0.8621 - val_loss: 1.7260 - val_acc: 0.2857
# Epoch 25/500
#
# Epoch 00025: val_loss improved from 1.72603 to 1.72140, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.7995 - acc: 0.8621 - val_loss: 1.7214 - val_acc: 0.2857
# Epoch 26/500
#
# Epoch 00026: val_loss improved from 1.72140 to 1.71671, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.7580 - acc: 0.8966 - val_loss: 1.7167 - val_acc: 0.2857
# Epoch 27/500
#
# Epoch 00027: val_loss improved from 1.71671 to 1.71210, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.7181 - acc: 0.8966 - val_loss: 1.7121 - val_acc: 0.2857
# Epoch 28/500
#
# Epoch 00028: val_loss improved from 1.71210 to 1.70692, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.6795 - acc: 0.9310 - val_loss: 1.7069 - val_acc: 0.2857
# Epoch 29/500
#
# Epoch 00029: val_loss improved from 1.70692 to 1.70121, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.6422 - acc: 0.9310 - val_loss: 1.7012 - val_acc: 0.2857
# Epoch 30/500
#
# Epoch 00030: val_loss improved from 1.70121 to 1.69410, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.6064 - acc: 0.9310 - val_loss: 1.6941 - val_acc: 0.2857
# Epoch 31/500
#
# Epoch 00031: val_loss improved from 1.69410 to 1.68745, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.5720 - acc: 0.9310 - val_loss: 1.6875 - val_acc: 0.2857
# Epoch 32/500
#
# Epoch 00032: val_loss improved from 1.68745 to 1.68249, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.5390 - acc: 0.9310 - val_loss: 1.6825 - val_acc: 0.2857
# Epoch 33/500
#
# Epoch 00033: val_loss improved from 1.68249 to 1.67730, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.5079 - acc: 0.9310 - val_loss: 1.6773 - val_acc: 0.2857
# Epoch 34/500
#
# Epoch 00034: val_loss improved from 1.67730 to 1.67245, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.4784 - acc: 0.9310 - val_loss: 1.6725 - val_acc: 0.2857
# Epoch 35/500
#
# Epoch 00035: val_loss improved from 1.67245 to 1.66684, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.4506 - acc: 0.9310 - val_loss: 1.6668 - val_acc: 0.2857
# Epoch 36/500
#
# Epoch 00036: val_loss improved from 1.66684 to 1.66014, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.4237 - acc: 0.9310 - val_loss: 1.6601 - val_acc: 0.2857
# Epoch 37/500
#
# Epoch 00037: val_loss improved from 1.66014 to 1.65236, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.3983 - acc: 0.9655 - val_loss: 1.6524 - val_acc: 0.4286
# Epoch 38/500
#
# Epoch 00038: val_loss improved from 1.65236 to 1.64542, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.3748 - acc: 0.9655 - val_loss: 1.6454 - val_acc: 0.4286
# Epoch 39/500
#
# Epoch 00039: val_loss improved from 1.64542 to 1.63993, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.3526 - acc: 0.9655 - val_loss: 1.6399 - val_acc: 0.4286
# Epoch 40/500
#
# Epoch 00040: val_loss improved from 1.63993 to 1.63396, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.3320 - acc: 0.9655 - val_loss: 1.6340 - val_acc: 0.4286
# Epoch 41/500
#
# Epoch 00041: val_loss improved from 1.63396 to 1.62738, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.3130 - acc: 0.9655 - val_loss: 1.6274 - val_acc: 0.4286
# Epoch 42/500
#
# Epoch 00042: val_loss improved from 1.62738 to 1.62044, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2948 - acc: 0.9655 - val_loss: 1.6204 - val_acc: 0.4286
# Epoch 43/500
#
# Epoch 00043: val_loss improved from 1.62044 to 1.61268, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2777 - acc: 0.9655 - val_loss: 1.6127 - val_acc: 0.4286
# Epoch 44/500
#
# Epoch 00044: val_loss improved from 1.61268 to 1.60416, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2618 - acc: 0.9655 - val_loss: 1.6042 - val_acc: 0.4286
# Epoch 45/500
#
# Epoch 00045: val_loss improved from 1.60416 to 1.59574, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2472 - acc: 0.9655 - val_loss: 1.5957 - val_acc: 0.4286
# Epoch 46/500
#
# Epoch 00046: val_loss improved from 1.59574 to 1.58790, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2336 - acc: 0.9655 - val_loss: 1.5879 - val_acc: 0.4286
# Epoch 47/500
#
# Epoch 00047: val_loss improved from 1.58790 to 1.57848, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2208 - acc: 0.9655 - val_loss: 1.5785 - val_acc: 0.4286
# Epoch 48/500
#
# Epoch 00048: val_loss improved from 1.57848 to 1.56791, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2089 - acc: 0.9655 - val_loss: 1.5679 - val_acc: 0.4286
# Epoch 49/500
#
# Epoch 00049: val_loss improved from 1.56791 to 1.55701, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1978 - acc: 0.9655 - val_loss: 1.5570 - val_acc: 0.4286
# Epoch 50/500
#
# Epoch 00050: val_loss improved from 1.55701 to 1.54531, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1873 - acc: 0.9655 - val_loss: 1.5453 - val_acc: 0.4286
# Epoch 51/500
#
# Epoch 00051: val_loss improved from 1.54531 to 1.53310, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1774 - acc: 0.9655 - val_loss: 1.5331 - val_acc: 0.4286
# Epoch 52/500
#
# Epoch 00052: val_loss improved from 1.53310 to 1.52432, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1681 - acc: 0.9655 - val_loss: 1.5243 - val_acc: 0.4286
# Epoch 53/500
#
# Epoch 00053: val_loss improved from 1.52432 to 1.51736, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1599 - acc: 0.9655 - val_loss: 1.5174 - val_acc: 0.4286
# Epoch 54/500
#
# Epoch 00054: val_loss improved from 1.51736 to 1.51073, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1520 - acc: 0.9655 - val_loss: 1.5107 - val_acc: 0.4286
# Epoch 55/500
#
# Epoch 00055: val_loss improved from 1.51073 to 1.50166, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1445 - acc: 0.9655 - val_loss: 1.5017 - val_acc: 0.4286
# Epoch 56/500
#
# Epoch 00056: val_loss improved from 1.50166 to 1.49038, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1373 - acc: 0.9655 - val_loss: 1.4904 - val_acc: 0.5714
# Epoch 57/500
#
# Epoch 00057: val_loss improved from 1.49038 to 1.47861, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1302 - acc: 0.9655 - val_loss: 1.4786 - val_acc: 0.5714
# Epoch 58/500
#
# Epoch 00058: val_loss improved from 1.47861 to 1.46651, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1234 - acc: 0.9655 - val_loss: 1.4665 - val_acc: 0.5714
# Epoch 59/500
#
# Epoch 00059: val_loss improved from 1.46651 to 1.45377, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1170 - acc: 0.9655 - val_loss: 1.4538 - val_acc: 0.5714
# Epoch 60/500
#
# Epoch 00060: val_loss improved from 1.45377 to 1.44153, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1107 - acc: 0.9655 - val_loss: 1.4415 - val_acc: 0.5714
# Epoch 61/500
#
# Epoch 00061: val_loss improved from 1.44153 to 1.43023, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1047 - acc: 0.9655 - val_loss: 1.4302 - val_acc: 0.5714
# Epoch 62/500
#
# Epoch 00062: val_loss improved from 1.43023 to 1.41989, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0990 - acc: 0.9655 - val_loss: 1.4199 - val_acc: 0.5714
# Epoch 63/500
#
# Epoch 00063: val_loss improved from 1.41989 to 1.41052, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0934 - acc: 0.9655 - val_loss: 1.4105 - val_acc: 0.5714
# Epoch 64/500
#
# Epoch 00064: val_loss improved from 1.41052 to 1.40288, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0880 - acc: 0.9655 - val_loss: 1.4029 - val_acc: 0.5714
# Epoch 65/500
#
# Epoch 00065: val_loss improved from 1.40288 to 1.39572, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0831 - acc: 0.9655 - val_loss: 1.3957 - val_acc: 0.5714
# Epoch 66/500
#
# Epoch 00066: val_loss improved from 1.39572 to 1.38973, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0784 - acc: 0.9655 - val_loss: 1.3897 - val_acc: 0.5714
# Epoch 67/500
#
# Epoch 00067: val_loss improved from 1.38973 to 1.38575, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0739 - acc: 0.9655 - val_loss: 1.3857 - val_acc: 0.5714
# Epoch 68/500
#
# Epoch 00068: val_loss improved from 1.38575 to 1.38263, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0699 - acc: 0.9655 - val_loss: 1.3826 - val_acc: 0.7143
# Epoch 69/500
#
# Epoch 00069: val_loss improved from 1.38263 to 1.38030, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0661 - acc: 1.0000 - val_loss: 1.3803 - val_acc: 0.7143
# Epoch 70/500
#
# Epoch 00070: val_loss improved from 1.38030 to 1.37806, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0623 - acc: 1.0000 - val_loss: 1.3781 - val_acc: 0.7143
# Epoch 71/500
#
# Epoch 00071: val_loss improved from 1.37806 to 1.37643, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0588 - acc: 1.0000 - val_loss: 1.3764 - val_acc: 0.7143
# Epoch 72/500
#
# Epoch 00072: val_loss improved from 1.37643 to 1.37603, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0555 - acc: 1.0000 - val_loss: 1.3760 - val_acc: 0.7143
# Epoch 73/500
#
# Epoch 00073: val_loss did not improve from 1.37603
# 29/29 [==============================] - 0s 344us/sample - loss: 0.0525 - acc: 1.0000 - val_loss: 1.3765 - val_acc: 0.7143
# Epoch 74/500
#
# Epoch 00074: val_loss did not improve from 1.37603
# 29/29 [==============================] - 0s 309us/sample - loss: 0.0497 - acc: 1.0000 - val_loss: 1.3774 - val_acc: 0.7143
# Epoch 75/500
#
# Epoch 00075: val_loss did not improve from 1.37603
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0470 - acc: 1.0000 - val_loss: 1.3792 - val_acc: 0.7143
# Epoch 76/500
#
# Epoch 00076: val_loss did not improve from 1.37603
# 29/29 [==============================] - 0s 346us/sample - loss: 0.0444 - acc: 1.0000 - val_loss: 1.3798 - val_acc: 0.7143
# Epoch 77/500
#
# Epoch 00077: val_loss did not improve from 1.37603
# 29/29 [==============================] - 0s 310us/sample - loss: 0.0439 - acc: 1.0000 - val_loss: 1.3804 - val_acc: 0.7143
# Epoch 78/500
#
# Epoch 00078: val_loss did not improve from 1.37603
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 29/29 [==============================] - 0s 380us/sample - loss: 0.0435 - acc: 1.0000 - val_loss: 1.3809 - val_acc: 0.7143
# Epoch 79/500
#
# Epoch 00079: val_loss did not improve from 1.37603
# 29/29 [==============================] - 0s 344us/sample - loss: 0.0430 - acc: 1.0000 - val_loss: 1.3810 - val_acc: 0.7143
# Epoch 80/500
#
# Epoch 00080: val_loss did not improve from 1.37603
# 29/29 [==============================] - 0s 378us/sample - loss: 0.0429 - acc: 1.0000 - val_loss: 1.3811 - val_acc: 0.7143
# Epoch 81/500
#
# Epoch 00081: val_loss did not improve from 1.37603
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 29/29 [==============================] - 0s 449us/sample - loss: 0.0428 - acc: 1.0000 - val_loss: 1.3811 - val_acc: 0.7143
# Epoch 82/500
#
# Epoch 00082: val_loss did not improve from 1.37603
# 29/29 [==============================] - 0s 344us/sample - loss: 0.0427 - acc: 1.0000 - val_loss: 1.3811 - val_acc: 0.7143

# %% [markdown]
# # Testing the model

# %%
[np.argmax(i) for i in model.predict(X_test)][:8]
# Out:
# [3, 4, 3, 4, 5, 6, 0]

# %%
[np.argmax(i) for i in y_test][:8]
# Out:
# [1, 2, 3, 4, 5, 6, 0]

# %% [markdown]
# # Posing new question to our model

# %%
def get_text():
    input_text  = ['Good evening']
    df_input = pd.DataFrame(input_text,columns=['questions'])
    df_input
    return df_input 

#load artifacts 
from tensorflow.keras.models import load_model
model = load_model('model-v1.h5')
# tokenizer_t to be used in encode_input_text
tokenizer_t = joblib.load('tokenizer_t.pkl')
# vocab to be used in bot_precaution
vocab = joblib.load('vocab.pkl')

def tokenizer(entry):
    tokens = entry.split()
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    tokens = [re_punc.sub('', w) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    tokens = [lemmatizer.lemmatize(w.lower()) for w in tokens]
#     stop_words = set(stopwords.words('english'))
#     tokens = [w for w in tokens if not w in stop_words]
    tokens = [word.lower() for word in tokens if len(word) > 1]
    return tokens

def remove_stop_words_for_input(tokenizer,df,feature):
    doc_without_stopwords = []
    entry = df[feature][0]
    tokens = tokenizer(entry)
    doc_without_stopwords.append(' '.join(tokens))
    df[feature] = doc_without_stopwords
    return df

def encode_input_text(tokenizer_t,df,feature):
    t = tokenizer_t
    entry = entry = [df[feature][0]]
    encoded = t.texts_to_sequences(entry)
    padded = pad_sequences(encoded, maxlen=8, padding='post')
    return padded

def get_pred(model,encoded_input):
    pred = np.argmax(model.predict(encoded_input))
    return pred

def bot_precausion(df_input,pred):
    words = df_input.questions[0].split()
    if len([w for w in words if w in vocab])==0 :
        pred = 1
    return pred

def get_response(df2,pred):
    upper_bound = df2.groupby('labels').get_group(pred).shape[0]
    r = np.random.randint(0,upper_bound)
    responses = list(df2.groupby('labels').get_group(pred).responses)
    return responses[r]

def bot_response(response,):
    print(response)
# Out:
# WARNING:tensorflow:From C:\Users\akhil\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\akhil\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
df_input = get_text()

#load artifacts 
tokenizer_t = joblib.load('tokenizer_t.pkl')
vocab = joblib.load('vocab.pkl')

df_input = remove_stop_words_for_input(tokenizer,df_input,'questions')
df_input
encoded_input = encode_input_text(tokenizer_t,df_input,'questions')
encoded_input

pred = get_pred(model,encoded_input)
pred
pred = bot_precausion(df_input,pred)

response = get_response(responses_df,pred)
bot_response(response)
# Out:
#       questions
# 0  good evening
# array([[27,  0,  0,  0,  0,  0,  0,  0]])
# 4
# Hello
