# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from pathlib import Path
import string
import re
import joblib
import json
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\akhil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def load_doc(jsonFile):
    with open(jsonFile) as file:
        Json_data = json.loads(file.read())
    return Json_data

data = load_doc('./intents.json')
data
# Out:
# {'intents': [{'tag': 'start_conversation',
#    'patterns': ['Hi there',
#     'Is anyone there?',
#     'Hey',
#     'Hola',
#     'Hello',
#     'Good day',
#     'Hi'],
#    'responses': ['Hello',
#     'Happy to have you here',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context': ['']},
#   {'tag': 'what_are_you',
#    'patterns': ['What is your name?',
#     'what are you?',
#     'who are you?',
#     'your name pls?'],
#    'responses': ["Hi, I'm  Bowhead Bot",
#     "I'm Bowhead Bot ",
#     'Call me Bowhead Bot'],
#    'context': ['']},
#   {'tag': 'end_conversation',
#    'patterns': ['Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['Have a lovely Day!',
#     'Bye',
#     'Buhbyee !',
#     'Happy to help you'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure', 'Have fun'],
#    'context': ['']},
#   {'tag': 'confused',
#    'patterns': [],
#    'responses': ['Sorry, kindly rephrase the question',
#     "Sorry, can't understand you",
#     'Please give me more information',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'options',
#    'patterns': ['How can you help me?',
#     'What can you do?',
#     'What help you provide?',
#     'How can you be helpful?',
#     'What support do you offered',
#     'What do you know?',
#     'what help?',
#     'What are you about?'],
#    'responses': ['I can help you get to know more about Bowhead Health and the services we provide, in particular, I can help you find Covid trails suitable to your needs'],
#    'context': ['']},
#   {'tag': 'covid_trials',
#    'patterns': ['What can you tell me about covid trials',
#     'I need some info about covid trials',
#     'Covid trials info needed',
#     'I want to know about covid trials',
#     'Show me covid trials info'],
#    'responses': ['Sure let me get that info for you',
#     'I will get that info for you',
#     'Getting the covid trails info',
#     'Gathering the trials information '],
#    'context': ['']}]}

# %%
def frame_data(feat_1,feat_2,is_pattern):
    is_pattern = is_pattern
    df = pd.DataFrame(columns=[feat_1,feat_2])
    for intent in data['intents']:
        if is_pattern:
            for pattern in intent['patterns']:
                w = pattern
                df_to_append = pd.Series([w,intent['tag']], index = df.columns)
                df = df.append(df_to_append,ignore_index=True)
        else:
            for response in intent['responses']:
                w = response
                df_to_append = pd.Series([w,intent['tag']], index = df.columns)
                df = df.append(df_to_append,ignore_index=True)
    return df

# %%
questions_df = frame_data('questions','labels',True)
questions_df
# Out:
#                                   questions              labels
# 0                                  Hi there  start_conversation
# 1                          Is anyone there?  start_conversation
# 2                                       Hey  start_conversation
# 3                                      Hola  start_conversation
# 4                                     Hello  start_conversation
# 5                                  Good day  start_conversation
# 6                                        Hi  start_conversation
# 7                        What is your name?        what_are_you
# 8                             what are you?        what_are_you
# 9                              who are you?        what_are_you
# 10                           your name pls?        what_are_you
# 11                                      Bye    end_conversation
# 12                            See you later    end_conversation
# 13                                  Goodbye    end_conversation
# 14                Nice chatting to you, bye    end_conversation
# 15                           Till next time    end_conversation
# 16                                   Thanks              thanks
# 17                                Thank you              thanks
# 18                           That's helpful              thanks
# 19                          Awesome, thanks              thanks
# 20                    Thanks for helping me              thanks
# 21                     How can you help me?             options
# 22                         What can you do?             options
# 23                   What help you provide?             options
# 24                  How can you be helpful?             options
# 25              What support do you offered             options
# 26                        What do you know?             options
# 27                               what help?             options
# 28                      What are you about?             options
# 29  What can you tell me about covid trials        covid_trials
# 30      I need some info about covid trials        covid_trials
# 31                 Covid trials info needed        covid_trials
# 32        I want to know about covid trials        covid_trials
# 33                Show me covid trials info        covid_trials

# %%
responses_df = frame_data('responses','labels',False)
responses_df
# Out:
#                                             responses              labels
# 0                                               Hello  start_conversation
# 1                              Happy to have you here  start_conversation
# 2                               Good to see you again  start_conversation
# 3                           Hi there, how can I help?  start_conversation
# 4                                Hi, I'm  Bowhead Bot        what_are_you
# 5                                    I'm Bowhead Bot         what_are_you
# 6                                 Call me Bowhead Bot        what_are_you
# 7                                  Have a lovely Day!    end_conversation
# 8                                                 Bye    end_conversation
# 9                                           Buhbyee !    end_conversation
# 10                                  Happy to help you    end_conversation
# 11                                     Happy to help!              thanks
# 12                                          Any time!              thanks
# 13                                        My pleasure              thanks
# 14                                           Have fun              thanks
# 15                Sorry, kindly rephrase the question            confused
# 16                        Sorry, can't understand you            confused
# 17                    Please give me more information            confused
# 18                              Not sure I understand            confused
# 19  I can help you get to know more about Bowhead ...             options
# 20                  Sure let me get that info for you        covid_trials
# 21                       I will get that info for you        covid_trials
# 22                      Getting the covid trails info        covid_trials
# 23                  Gathering the trials information         covid_trials

# %% [markdown]
# # For creating tokens and vocab of training data;this vocab is later used when testing new user input(testing the bot)

# %%
lemmatizer = WordNetLemmatizer()

vocab = Counter()
labels = []
def tokenizer(entry):
    tokens = entry.split()
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    tokens = [re_punc.sub('', w) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    tokens = [lemmatizer.lemmatize(w.lower()) for w in tokens]
#     stop_words = set(stopwords.words('english'))
#     tokens = [w for w in tokens if not w in stop_words]
    tokens = [word.lower() for word in tokens if len(word) > 1]
    return tokens

def remove_stop_words(tokenizer,df,feature):
    doc_without_stopwords = []
    for entry in df[feature]:
        tokens = tokenizer(entry)
        joblib.dump(tokens,'tokens.pkl')
        doc_without_stopwords.append(' '.join(tokens))
    df[feature] = doc_without_stopwords
    return 

def create_vocab(tokenizer,df,feature):
    for entry in df[feature]:
        tokens = tokenizer(entry)   
        vocab.update(tokens)
    joblib.dump(vocab,'vocab.pkl')
    return 


create_vocab(tokenizer,questions_df,'questions')
remove_stop_words(tokenizer,questions_df,'questions')

# %% [markdown]
# # Creating training and test data and storing the indexes

# %%
# Creating a test list containing only the first question of each group after grouping them according to their labels.
test_list = list(questions_df.groupby(by='labels',as_index=False).first()['questions'])
test_list

# The index of the above test observations taken from the dataframe df1
test_index = []
for i,_ in enumerate(test_list):
    idx = questions_df[questions_df.questions == test_list[i]].index[0]
    test_index.append(idx)
test_index

# Train index
train_index = [i for i in questions_df.index if i not in test_index]
train_index
# Out:
# ['what can you tell me about covid trial',
#  'bye',
#  'how can you help me',
#  'hi there',
#  'thanks',
#  'what is your name']
# [29, 11, 21, 0, 16, 7]
# [1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  8,
#  9,
#  10,
#  12,
#  13,
#  14,
#  15,
#  17,
#  18,
#  19,
#  20,
#  22,
#  23,
#  24,
#  25,
#  26,
#  27,
#  28,
#  30,
#  31,
#  32,
#  33]

# %% [markdown]
# # Initializing a tokenizer, fitting it on to questions df and encoding the questions_df

# %%
def encoder(df,feature):
#     text = ' '.join(list(vocab.keys()))
#     from tensorflow.keras.preprocessing.text import text_to_word_sequence
    t = Tokenizer()
    entries = [entry for entry in df[feature]]
    print(entries)
    #step1 To create dictionary having 'keys' as words from each entry(sentences) and 'values' are randomly assigned by tokenizer.
    t.fit_on_texts(entries)
    print(t.word_index)
    joblib.dump(t,'tokenizer_t.pkl')
    vocab_size = len(t.word_index) + 1
    print(vocab_size)
    entries = [entry for entry in df[feature]]
    max_length = max([len(s.split()) for s in entries])
    print(max_length)
    #setp2 To see the output of the dataframe when dictionary 'values' from the above created dictionary in step1 are used in the place of the words in the sentences
    encoded = t.texts_to_sequences(entries)
    print(encoded)
    padded = pad_sequences(encoded, maxlen=max_length, padding='post')
    return padded, vocab_size

# %%
X,vocab_size = encoder(questions_df,'questions')
X
questions_df_encoded = pd.DataFrame(X)
questions_df_encoded['labels'] = questions_df.labels
questions_df_encoded
# Out:
# ['hi there', 'is anyone there', 'hey', 'hola', 'hello', 'good day', 'hi', 'what is your name', 'what are you', 'who are you', 'your name pls', 'bye', 'see you later', 'goodbye', 'nice chatting to you bye', 'till next time', 'thanks', 'thank you', 'thats helpful', 'awesome thanks', 'thanks for helping me', 'how can you help me', 'what can you do', 'what help you provide', 'how can you be helpful', 'what support do you offered', 'what do you know', 'what help', 'what are you about', 'what can you tell me about covid trial', 'need some info about covid trial', 'covid trial info needed', 'want to know about covid trial', 'show me covid trial info']
# {'you': 1, 'what': 2, 'covid': 3, 'trial': 4, 'me': 5, 'can': 6, 'about': 7, 'are': 8, 'thanks': 9, 'help': 10, 'do': 11, 'info': 12, 'hi': 13, 'there': 14, 'is': 15, 'your': 16, 'name': 17, 'bye': 18, 'to': 19, 'helpful': 20, 'how': 21, 'know': 22, 'anyone': 23, 'hey': 24, 'hola': 25, 'hello': 26, 'good': 27, 'day': 28, 'who': 29, 'pls': 30, 'see': 31, 'later': 32, 'goodbye': 33, 'nice': 34, 'chatting': 35, 'till': 36, 'next': 37, 'time': 38, 'thank': 39, 'thats': 40, 'awesome': 41, 'for': 42, 'helping': 43, 'provide': 44, 'be': 45, 'support': 46, 'offered': 47, 'tell': 48, 'need': 49, 'some': 50, 'needed': 51, 'want': 52, 'show': 53}
# 54
# ['hi there', 'is anyone there', 'hey', 'hola', 'hello', 'good day', 'hi', 'what is your name', 'what are you', 'who are you', 'your name pls', 'bye', 'see you later', 'goodbye', 'nice chatting to you bye', 'till next time', 'thanks', 'thank you', 'thats helpful', 'awesome thanks', 'thanks for helping me', 'how can you help me', 'what can you do', 'what help you provide', 'how can you be helpful', 'what support do you offered', 'what do you know', 'what help', 'what are you about', 'what can you tell me about covid trial', 'need some info about covid trial', 'covid trial info needed', 'want to know about covid trial', 'show me covid trial info']
# 8
# [[13, 14], [15, 23, 14], [24], [25], [26], [27, 28], [13], [2, 15, 16, 17], [2, 8, 1], [29, 8, 1], [16, 17, 30], [18], [31, 1, 32], [33], [34, 35, 19, 1, 18], [36, 37, 38], [9], [39, 1], [40, 20], [41, 9], [9, 42, 43, 5], [21, 6, 1, 10, 5], [2, 6, 1, 11], [2, 10, 1, 44], [21, 6, 1, 45, 20], [2, 46, 11, 1, 47], [2, 11, 1, 22], [2, 10], [2, 8, 1, 7], [2, 6, 1, 48, 5, 7, 3, 4], [49, 50, 12, 7, 3, 4], [3, 4, 12, 51], [52, 19, 22, 7, 3, 4], [53, 5, 3, 4, 12]]
# array([[13, 14,  0,  0,  0,  0,  0,  0],
#        [15, 23, 14,  0,  0,  0,  0,  0],
#        [24,  0,  0,  0,  0,  0,  0,  0],
#        [25,  0,  0,  0,  0,  0,  0,  0],
#        [26,  0,  0,  0,  0,  0,  0,  0],
#        [27, 28,  0,  0,  0,  0,  0,  0],
#        [13,  0,  0,  0,  0,  0,  0,  0],
#        [ 2, 15, 16, 17,  0,  0,  0,  0],
#        [ 2,  8,  1,  0,  0,  0,  0,  0],
#        [29,  8,  1,  0,  0,  0,  0,  0],
#        [16, 17, 30,  0,  0,  0,  0,  0],
#        [18,  0,  0,  0,  0,  0,  0,  0],
#        [31,  1, 32,  0,  0,  0,  0,  0],
#        [33,  0,  0,  0,  0,  0,  0,  0],
#        [34, 35, 19,  1, 18,  0,  0,  0],
#        [36, 37, 38,  0,  0,  0,  0,  0],
#        [ 9,  0,  0,  0,  0,  0,  0,  0],
#        [39,  1,  0,  0,  0,  0,  0,  0],
#        [40, 20,  0,  0,  0,  0,  0,  0],
#        [41,  9,  0,  0,  0,  0,  0,  0],
#        [ 9, 42, 43,  5,  0,  0,  0,  0],
#        [21,  6,  1, 10,  5,  0,  0,  0],
#        [ 2,  6,  1, 11,  0,  0,  0,  0],
#        [ 2, 10,  1, 44,  0,  0,  0,  0],
#        [21,  6,  1, 45, 20,  0,  0,  0],
#        [ 2, 46, 11,  1, 47,  0,  0,  0],
#        [ 2, 11,  1, 22,  0,  0,  0,  0],
#        [ 2, 10,  0,  0,  0,  0,  0,  0],
#        [ 2,  8,  1,  7,  0,  0,  0,  0],
#        [ 2,  6,  1, 48,  5,  7,  3,  4],
#        [49, 50, 12,  7,  3,  4,  0,  0],
#        [ 3,  4, 12, 51,  0,  0,  0,  0],
#        [52, 19, 22,  7,  3,  4,  0,  0],
#        [53,  5,  3,  4, 12,  0,  0,  0]])
#      0   1   2   3   4  5  6  7              labels
# 0   13  14   0   0   0  0  0  0  start_conversation
# 1   15  23  14   0   0  0  0  0  start_conversation
# 2   24   0   0   0   0  0  0  0  start_conversation
# 3   25   0   0   0   0  0  0  0  start_conversation
# 4   26   0   0   0   0  0  0  0  start_conversation
# 5   27  28   0   0   0  0  0  0  start_conversation
# 6   13   0   0   0   0  0  0  0  start_conversation
# 7    2  15  16  17   0  0  0  0        what_are_you
# 8    2   8   1   0   0  0  0  0        what_are_you
# 9   29   8   1   0   0  0  0  0        what_are_you
# 10  16  17  30   0   0  0  0  0        what_are_you
# 11  18   0   0   0   0  0  0  0    end_conversation
# 12  31   1  32   0   0  0  0  0    end_conversation
# 13  33   0   0   0   0  0  0  0    end_conversation
# 14  34  35  19   1  18  0  0  0    end_conversation
# 15  36  37  38   0   0  0  0  0    end_conversation
# 16   9   0   0   0   0  0  0  0              thanks
# 17  39   1   0   0   0  0  0  0              thanks
# 18  40  20   0   0   0  0  0  0              thanks
# 19  41   9   0   0   0  0  0  0              thanks
# 20   9  42  43   5   0  0  0  0              thanks
# 21  21   6   1  10   5  0  0  0             options
# 22   2   6   1  11   0  0  0  0             options
# 23   2  10   1  44   0  0  0  0             options
# 24  21   6   1  45  20  0  0  0             options
# 25   2  46  11   1  47  0  0  0             options
# 26   2  11   1  22   0  0  0  0             options
# 27   2  10   0   0   0  0  0  0             options
# 28   2   8   1   7   0  0  0  0             options
# 29   2   6   1  48   5  7  3  4        covid_trials
# 30  49  50  12   7   3  4  0  0        covid_trials
# 31   3   4  12  51   0  0  0  0        covid_trials
# 32  52  19  22   7   3  4  0  0        covid_trials
# 33  53   5   3   4  12  0  0  0        covid_trials

# %%
#Creating 2 observations with 'confused' label and appending them to dataframe.
for i in range(0,2):
    dt = [0]*8
    dt.append('confused')
    dt = [dt]
    pd.DataFrame(dt).rename(columns = {8:'labels'})
    questions_df_encoded = questions_df_encoded.append(pd.DataFrame(dt).rename(columns = {8:'labels'}),ignore_index=True)
    
questions_df_encoded
# Out:
#    0  1  2  3  4  5  6  7    labels
# 0  0  0  0  0  0  0  0  0  confused
#    0  1  2  3  4  5  6  7    labels
# 0  0  0  0  0  0  0  0  0  confused
#      0   1   2   3   4  5  6  7              labels
# 0   13  14   0   0   0  0  0  0  start_conversation
# 1   15  23  14   0   0  0  0  0  start_conversation
# 2   24   0   0   0   0  0  0  0  start_conversation
# 3   25   0   0   0   0  0  0  0  start_conversation
# 4   26   0   0   0   0  0  0  0  start_conversation
# 5   27  28   0   0   0  0  0  0  start_conversation
# 6   13   0   0   0   0  0  0  0  start_conversation
# 7    2  15  16  17   0  0  0  0        what_are_you
# 8    2   8   1   0   0  0  0  0        what_are_you
# 9   29   8   1   0   0  0  0  0        what_are_you
# 10  16  17  30   0   0  0  0  0        what_are_you
# 11  18   0   0   0   0  0  0  0    end_conversation
# 12  31   1  32   0   0  0  0  0    end_conversation
# 13  33   0   0   0   0  0  0  0    end_conversation
# 14  34  35  19   1  18  0  0  0    end_conversation
# 15  36  37  38   0   0  0  0  0    end_conversation
# 16   9   0   0   0   0  0  0  0              thanks
# 17  39   1   0   0   0  0  0  0              thanks
# 18  40  20   0   0   0  0  0  0              thanks
# 19  41   9   0   0   0  0  0  0              thanks
# 20   9  42  43   5   0  0  0  0              thanks
# 21  21   6   1  10   5  0  0  0             options
# 22   2   6   1  11   0  0  0  0             options
# 23   2  10   1  44   0  0  0  0             options
# 24  21   6   1  45  20  0  0  0             options
# 25   2  46  11   1  47  0  0  0             options
# 26   2  11   1  22   0  0  0  0             options
# 27   2  10   0   0   0  0  0  0             options
# 28   2   8   1   7   0  0  0  0             options
# 29   2   6   1  48   5  7  3  4        covid_trials
# 30  49  50  12   7   3  4  0  0        covid_trials
# 31   3   4  12  51   0  0  0  0        covid_trials
# 32  52  19  22   7   3  4  0  0        covid_trials
# 33  53   5   3   4  12  0  0  0        covid_trials
# 34   0   0   0   0   0  0  0  0            confused
# 35   0   0   0   0   0  0  0  0            confused

# %%
# Appending one of the confused labeled observation to train index
train_index.append(34)
# Appending one of the confused labeled observation to test index
test_index.append(35)

# %% [markdown]
# # Encoding the labels of questions_df_encoded and then later responses_df

# %%
# Encoding the 'labels' with values choosen(random) by labelEncoder 
from sklearn.preprocessing import LabelEncoder
lable_enc = LabelEncoder()

labl = lable_enc.fit_transform(questions_df_encoded.labels)
labl

mapper = {}
for index,key in enumerate(questions_df_encoded.labels):
    if key not in mapper.keys():
        mapper[key] = labl[index]
mapper
# Out:
# array([4, 4, 4, 4, 4, 4, 4, 6, 6, 6, 6, 2, 2, 2, 2, 2, 5, 5, 5, 5, 5, 3,
#        3, 3, 3, 3, 3, 3, 3, 1, 1, 1, 1, 1, 0, 0])
# {'start_conversation': 4,
#  'what_are_you': 6,
#  'end_conversation': 2,
#  'thanks': 5,
#  'options': 3,
#  'covid_trials': 1,
#  'confused': 0}

# %%
# Encoding the labels of responses dataframe df2 with values choosen from questions dataframe df1.
responses_df.labels = responses_df.labels.map(mapper).astype({'labels': 'int32'})
responses_df
# Out:
#                                             responses  labels
# 0                                               Hello       4
# 1                              Happy to have you here       4
# 2                               Good to see you again       4
# 3                           Hi there, how can I help?       4
# 4                                Hi, I'm  Bowhead Bot       6
# 5                                    I'm Bowhead Bot        6
# 6                                 Call me Bowhead Bot       6
# 7                                  Have a lovely Day!       2
# 8                                                 Bye       2
# 9                                           Buhbyee !       2
# 10                                  Happy to help you       2
# 11                                     Happy to help!       5
# 12                                          Any time!       5
# 13                                        My pleasure       5
# 14                                           Have fun       5
# 15                Sorry, kindly rephrase the question       0
# 16                        Sorry, can't understand you       0
# 17                    Please give me more information       0
# 18                              Not sure I understand       0
# 19  I can help you get to know more about Bowhead ...       3
# 20                  Sure let me get that info for you       1
# 21                       I will get that info for you       1
# 22                      Getting the covid trails info       1
# 23                  Gathering the trials information        1

# %% [markdown]
# # Creating train and test for the model based on the above calculated indexes

# %%
train = questions_df_encoded.loc[train_index]
test = questions_df_encoded.loc[test_index]


X_train = train.drop(columns=['labels'],axis=1)
y_train = train.labels
X_test = test.drop(columns=['labels'],axis=1)
y_test = test.labels

y_train =pd.get_dummies(y_train).values
y_test =pd.get_dummies(y_test).values

# %%
y_train[0].shape,y_test[0].shape
X_train.shape
# Out:
# ((7,), (7,))
# (29, 8)

# %%
max_length = X_train.shape[1]
max_length
output = 9
# Out:
# 8

# %% [markdown]
# # Model construction

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
checkpoint = ModelCheckpoint("model-v1.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 3, verbose = 1, min_delta = 0.0001)
callbacks = [early_stopping,checkpoint,reduce_lr]


def define_model(vocab_size, max_length):
    model = Sequential()
    model.add(Embedding(vocab_size,300, input_length=max_length))
    model.add(Conv1D(filters=64, kernel_size=4, activation='relu'))
    model.add(MaxPooling1D(pool_size=4))
    model.add(Flatten())
#     model.add(Dense(32, activation='relu'))
    model.add(Dense(7, activation='softmax'))
    
    
    # compile network
#     model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.compile(loss = 'categorical_crossentropy',
              # optimizer = Adam(lr=0.001),
              optimizer = 'adam',
              metrics = ['accuracy'])
    
    # summarize defined model
    model.summary()
#     plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
model = define_model(vocab_size, max_length)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 8, 300)            16200
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 5, 64)             76864
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 1, 64)             0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 93,519
# Trainable params: 93,519
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=500, verbose=1,validation_data=(X_test,y_test),callbacks=callbacks)
# Out:
# Train on 29 samples, validate on 7 samples
# Epoch 1/500
#
# Epoch 00001: val_loss improved from inf to 1.92803, saving model to model-v1.h5
# 29/29 [==============================] - 1s 20ms/sample - loss: 1.9430 - acc: 0.1034 - val_loss: 1.9280 - val_acc: 0.2857
# Epoch 2/500
#
# Epoch 00002: val_loss improved from 1.92803 to 1.91909, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.8777 - acc: 0.4483 - val_loss: 1.9191 - val_acc: 0.1429
# Epoch 3/500
#
# Epoch 00003: val_loss improved from 1.91909 to 1.91268, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.8243 - acc: 0.5172 - val_loss: 1.9127 - val_acc: 0.2857
# Epoch 4/500
#
# Epoch 00004: val_loss improved from 1.91268 to 1.90570, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.7772 - acc: 0.5517 - val_loss: 1.9057 - val_acc: 0.2857
# Epoch 5/500
#
# Epoch 00005: val_loss improved from 1.90570 to 1.89679, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.7321 - acc: 0.5862 - val_loss: 1.8968 - val_acc: 0.2857
# Epoch 6/500
#
# Epoch 00006: val_loss improved from 1.89679 to 1.88778, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.6871 - acc: 0.5862 - val_loss: 1.8878 - val_acc: 0.2857
# Epoch 7/500
#
# Epoch 00007: val_loss improved from 1.88778 to 1.87953, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.6417 - acc: 0.5862 - val_loss: 1.8795 - val_acc: 0.2857
# Epoch 8/500
#
# Epoch 00008: val_loss improved from 1.87953 to 1.87242, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.5963 - acc: 0.6207 - val_loss: 1.8724 - val_acc: 0.2857
# Epoch 9/500
#
# Epoch 00009: val_loss improved from 1.87242 to 1.86610, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.5509 - acc: 0.6552 - val_loss: 1.8661 - val_acc: 0.2857
# Epoch 10/500
#
# Epoch 00010: val_loss improved from 1.86610 to 1.86000, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.5049 - acc: 0.6552 - val_loss: 1.8600 - val_acc: 0.2857
# Epoch 11/500
#
# Epoch 00011: val_loss improved from 1.86000 to 1.85282, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.4588 - acc: 0.6552 - val_loss: 1.8528 - val_acc: 0.2857
# Epoch 12/500
#
# Epoch 00012: val_loss improved from 1.85282 to 1.84527, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.4128 - acc: 0.6552 - val_loss: 1.8453 - val_acc: 0.2857
# Epoch 13/500
#
# Epoch 00013: val_loss improved from 1.84527 to 1.83699, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.3666 - acc: 0.6552 - val_loss: 1.8370 - val_acc: 0.2857
# Epoch 14/500
#
# Epoch 00014: val_loss improved from 1.83699 to 1.82826, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.3201 - acc: 0.6897 - val_loss: 1.8283 - val_acc: 0.2857
# Epoch 15/500
#
# Epoch 00015: val_loss improved from 1.82826 to 1.81953, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 1.2735 - acc: 0.7241 - val_loss: 1.8195 - val_acc: 0.2857
# Epoch 16/500
#
# Epoch 00016: val_loss improved from 1.81953 to 1.81120, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.2271 - acc: 0.7241 - val_loss: 1.8112 - val_acc: 0.2857
# Epoch 17/500
#
# Epoch 00017: val_loss improved from 1.81120 to 1.80263, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.1804 - acc: 0.7931 - val_loss: 1.8026 - val_acc: 0.2857
# Epoch 18/500
#
# Epoch 00018: val_loss improved from 1.80263 to 1.79329, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.1335 - acc: 0.7931 - val_loss: 1.7933 - val_acc: 0.2857
# Epoch 19/500
#
# Epoch 00019: val_loss improved from 1.79329 to 1.78273, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.0867 - acc: 0.7931 - val_loss: 1.7827 - val_acc: 0.2857
# Epoch 20/500
#
# Epoch 00020: val_loss improved from 1.78273 to 1.77113, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 1.0400 - acc: 0.8621 - val_loss: 1.7711 - val_acc: 0.2857
# Epoch 21/500
#
# Epoch 00021: val_loss improved from 1.77113 to 1.75872, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.9935 - acc: 0.8621 - val_loss: 1.7587 - val_acc: 0.2857
# Epoch 22/500
#
# Epoch 00022: val_loss improved from 1.75872 to 1.74589, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.9476 - acc: 0.8621 - val_loss: 1.7459 - val_acc: 0.2857
# Epoch 23/500
#
# Epoch 00023: val_loss improved from 1.74589 to 1.73298, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.9022 - acc: 0.8966 - val_loss: 1.7330 - val_acc: 0.2857
# Epoch 24/500
#
# Epoch 00024: val_loss improved from 1.73298 to 1.71954, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.8577 - acc: 0.8966 - val_loss: 1.7195 - val_acc: 0.2857
# Epoch 25/500
#
# Epoch 00025: val_loss improved from 1.71954 to 1.70608, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.8139 - acc: 0.8966 - val_loss: 1.7061 - val_acc: 0.2857
# Epoch 26/500
#
# Epoch 00026: val_loss improved from 1.70608 to 1.69247, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.7712 - acc: 0.8966 - val_loss: 1.6925 - val_acc: 0.2857
# Epoch 27/500
#
# Epoch 00027: val_loss improved from 1.69247 to 1.67928, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.7293 - acc: 0.8966 - val_loss: 1.6793 - val_acc: 0.2857
# Epoch 28/500
#
# Epoch 00028: val_loss improved from 1.67928 to 1.66797, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.6884 - acc: 0.8966 - val_loss: 1.6680 - val_acc: 0.4286
# Epoch 29/500
#
# Epoch 00029: val_loss improved from 1.66797 to 1.65809, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.6491 - acc: 0.8966 - val_loss: 1.6581 - val_acc: 0.4286
# Epoch 30/500
#
# Epoch 00030: val_loss improved from 1.65809 to 1.64823, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.6113 - acc: 0.9310 - val_loss: 1.6482 - val_acc: 0.4286
# Epoch 31/500
#
# Epoch 00031: val_loss improved from 1.64823 to 1.63752, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.5749 - acc: 0.9310 - val_loss: 1.6375 - val_acc: 0.4286
# Epoch 32/500
#
# Epoch 00032: val_loss improved from 1.63752 to 1.62605, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.5398 - acc: 0.9310 - val_loss: 1.6260 - val_acc: 0.4286
# Epoch 33/500
#
# Epoch 00033: val_loss improved from 1.62605 to 1.61484, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.5061 - acc: 0.9310 - val_loss: 1.6148 - val_acc: 0.4286
# Epoch 34/500
#
# Epoch 00034: val_loss improved from 1.61484 to 1.60355, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.4739 - acc: 0.9310 - val_loss: 1.6036 - val_acc: 0.4286
# Epoch 35/500
#
# Epoch 00035: val_loss improved from 1.60355 to 1.59384, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.4434 - acc: 0.9310 - val_loss: 1.5938 - val_acc: 0.4286
# Epoch 36/500
#
# Epoch 00036: val_loss improved from 1.59384 to 1.58473, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.4148 - acc: 0.9310 - val_loss: 1.5847 - val_acc: 0.4286
# Epoch 37/500
#
# Epoch 00037: val_loss improved from 1.58473 to 1.57614, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.3877 - acc: 0.9310 - val_loss: 1.5761 - val_acc: 0.4286
# Epoch 38/500
#
# Epoch 00038: val_loss improved from 1.57614 to 1.56899, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.3623 - acc: 0.9310 - val_loss: 1.5690 - val_acc: 0.4286
# Epoch 39/500
#
# Epoch 00039: val_loss improved from 1.56899 to 1.56191, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.3384 - acc: 0.9310 - val_loss: 1.5619 - val_acc: 0.4286
# Epoch 40/500
#
# Epoch 00040: val_loss improved from 1.56191 to 1.55410, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.3158 - acc: 0.9310 - val_loss: 1.5541 - val_acc: 0.4286
# Epoch 41/500
#
# Epoch 00041: val_loss improved from 1.55410 to 1.54453, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.2947 - acc: 0.9310 - val_loss: 1.5445 - val_acc: 0.4286
# Epoch 42/500
#
# Epoch 00042: val_loss improved from 1.54453 to 1.53348, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2751 - acc: 0.9655 - val_loss: 1.5335 - val_acc: 0.4286
# Epoch 43/500
#
# Epoch 00043: val_loss improved from 1.53348 to 1.52176, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2565 - acc: 0.9655 - val_loss: 1.5218 - val_acc: 0.4286
# Epoch 44/500
#
# Epoch 00044: val_loss improved from 1.52176 to 1.50952, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2390 - acc: 0.9655 - val_loss: 1.5095 - val_acc: 0.4286
# Epoch 45/500
#
# Epoch 00045: val_loss improved from 1.50952 to 1.49764, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.2226 - acc: 0.9655 - val_loss: 1.4976 - val_acc: 0.4286
# Epoch 46/500
#
# Epoch 00046: val_loss improved from 1.49764 to 1.48556, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.2073 - acc: 0.9655 - val_loss: 1.4856 - val_acc: 0.4286
# Epoch 47/500
#
# Epoch 00047: val_loss improved from 1.48556 to 1.47373, saving model to model-v1.h5
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.1930 - acc: 0.9655 - val_loss: 1.4737 - val_acc: 0.4286
# Epoch 48/500
#
# Epoch 00048: val_loss improved from 1.47373 to 1.46229, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1798 - acc: 0.9655 - val_loss: 1.4623 - val_acc: 0.4286
# Epoch 49/500
#
# Epoch 00049: val_loss improved from 1.46229 to 1.45186, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1676 - acc: 0.9655 - val_loss: 1.4519 - val_acc: 0.4286
# Epoch 50/500
#
# Epoch 00050: val_loss improved from 1.45186 to 1.44197, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1561 - acc: 0.9655 - val_loss: 1.4420 - val_acc: 0.4286
# Epoch 51/500
#
# Epoch 00051: val_loss improved from 1.44197 to 1.43255, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1453 - acc: 0.9655 - val_loss: 1.4326 - val_acc: 0.4286
# Epoch 52/500
#
# Epoch 00052: val_loss improved from 1.43255 to 1.42363, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1352 - acc: 0.9655 - val_loss: 1.4236 - val_acc: 0.4286
# Epoch 53/500
#
# Epoch 00053: val_loss improved from 1.42363 to 1.41596, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1257 - acc: 0.9655 - val_loss: 1.4160 - val_acc: 0.5714
# Epoch 54/500
#
# Epoch 00054: val_loss improved from 1.41596 to 1.40782, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1168 - acc: 0.9655 - val_loss: 1.4078 - val_acc: 0.5714
# Epoch 55/500
#
# Epoch 00055: val_loss improved from 1.40782 to 1.40007, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1083 - acc: 0.9655 - val_loss: 1.4001 - val_acc: 0.7143
# Epoch 56/500
#
# Epoch 00056: val_loss improved from 1.40007 to 1.39406, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.1002 - acc: 1.0000 - val_loss: 1.3941 - val_acc: 0.7143
# Epoch 57/500
#
# Epoch 00057: val_loss improved from 1.39406 to 1.39043, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0928 - acc: 1.0000 - val_loss: 1.3904 - val_acc: 0.7143
# Epoch 58/500
#
# Epoch 00058: val_loss improved from 1.39043 to 1.38829, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0863 - acc: 1.0000 - val_loss: 1.3883 - val_acc: 0.7143
# Epoch 59/500
#
# Epoch 00059: val_loss improved from 1.38829 to 1.38714, saving model to model-v1.h5
# 29/29 [==============================] - 0s 1ms/sample - loss: 0.0803 - acc: 1.0000 - val_loss: 1.3871 - val_acc: 0.7143
# Epoch 60/500
#
# Epoch 00060: val_loss did not improve from 1.38714
# 29/29 [==============================] - 0s 276us/sample - loss: 0.0748 - acc: 1.0000 - val_loss: 1.3876 - val_acc: 0.7143
# Epoch 61/500
#
# Epoch 00061: val_loss did not improve from 1.38714
# 29/29 [==============================] - 0s 250us/sample - loss: 0.0698 - acc: 1.0000 - val_loss: 1.3900 - val_acc: 0.7143
# Epoch 62/500
#
# Epoch 00062: val_loss did not improve from 1.38714
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 29/29 [==============================] - 0s 2ms/sample - loss: 0.0655 - acc: 1.0000 - val_loss: 1.3920 - val_acc: 0.7143
# Epoch 63/500
#
# Epoch 00063: val_loss did not improve from 1.38714
# 29/29 [==============================] - 0s 393us/sample - loss: 0.0613 - acc: 1.0000 - val_loss: 1.3923 - val_acc: 0.7143
# Epoch 64/500
#
# Epoch 00064: val_loss did not improve from 1.38714
# 29/29 [==============================] - 0s 426us/sample - loss: 0.0605 - acc: 1.0000 - val_loss: 1.3925 - val_acc: 0.7143
# Epoch 65/500
#
# Epoch 00065: val_loss did not improve from 1.38714
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 29/29 [==============================] - 0s 392us/sample - loss: 0.0597 - acc: 1.0000 - val_loss: 1.3927 - val_acc: 0.7143
# Epoch 66/500
#
# Epoch 00066: val_loss did not improve from 1.38714
# 29/29 [==============================] - 0s 353us/sample - loss: 0.0589 - acc: 1.0000 - val_loss: 1.3927 - val_acc: 0.7143
# Epoch 67/500
#
# Epoch 00067: val_loss did not improve from 1.38714
# 29/29 [==============================] - 0s 434us/sample - loss: 0.0588 - acc: 1.0000 - val_loss: 1.3927 - val_acc: 0.7143
# Epoch 68/500
#
# Epoch 00068: val_loss did not improve from 1.38714
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 29/29 [==============================] - 0s 332us/sample - loss: 0.0586 - acc: 1.0000 - val_loss: 1.3927 - val_acc: 0.7143
# Epoch 69/500
#
# Epoch 00069: val_loss did not improve from 1.38714
# 29/29 [==============================] - 0s 368us/sample - loss: 0.0585 - acc: 1.0000 - val_loss: 1.3927 - val_acc: 0.7143

# %% [markdown]
# # Testing the model

# %%
[np.argmax(i) for i in model.predict(X_test)][:8]
# Out:
# [3, 4, 3, 4, 5, 6, 0]

# %%
[np.argmax(i) for i in y_test][:8]
# Out:
# [1, 2, 3, 4, 5, 6, 0]

# %% [markdown]
# # Posing new question to our model

# %%
def get_text():
    input_text  = ['Good evening']
    df_input = pd.DataFrame(input_text,columns=['questions'])
    df_input
    return df_input 

#load artifacts 
from tensorflow.keras.models import load_model
model = load_model('model-v1.h5')
# tokenizer_t to be used in encode_input_text
tokenizer_t = joblib.load('tokenizer_t.pkl')
# vocab to be used in bot_precaution
vocab = joblib.load('vocab.pkl')

def tokenizer(entry):
    tokens = entry.split()
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    tokens = [re_punc.sub('', w) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    tokens = [lemmatizer.lemmatize(w.lower()) for w in tokens]
#     stop_words = set(stopwords.words('english'))
#     tokens = [w for w in tokens if not w in stop_words]
    tokens = [word.lower() for word in tokens if len(word) > 1]
    return tokens

def remove_stop_words_for_input(tokenizer,df,feature):
    doc_without_stopwords = []
    entry = df[feature][0]
    tokens = tokenizer(entry)
    doc_without_stopwords.append(' '.join(tokens))
    df[feature] = doc_without_stopwords
    return df

def encode_input_text(tokenizer_t,df,feature):
    t = tokenizer_t
    entry = entry = [df[feature][0]]
    encoded = t.texts_to_sequences(entry)
    padded = pad_sequences(encoded, maxlen=8, padding='post')
    return padded

def get_pred(model,encoded_input):
    pred = np.argmax(model.predict(encoded_input))
    return pred

def bot_precausion(df_input,pred):
    words = df_input.questions[0].split()
    if len([w for w in words if w in vocab])==0 :
        pred = 1
    return pred

def get_response(df2,pred):
    upper_bound = df2.groupby('labels').get_group(pred).shape[0]
    r = np.random.randint(0,upper_bound)
    responses = list(df2.groupby('labels').get_group(pred).responses)
    return responses[r]

def bot_response(response,):
    print(response)

# %%
df_input = get_text()

#load artifacts 
tokenizer_t = joblib.load('tokenizer_t.pkl')
vocab = joblib.load('vocab.pkl')

df_input = remove_stop_words_for_input(tokenizer,df_input,'questions')
df_input
encoded_input = encode_input_text(tokenizer_t,df_input,'questions')
encoded_input

pred = get_pred(model,encoded_input)
pred
pred = bot_precausion(df_input,pred)

response = get_response(responses_df,pred)
bot_response(response)
# Out:
#       questions
# 0  good evening
# array([[27,  0,  0,  0,  0,  0,  0,  0]])
# 4
# Good to see you again
